# %%
import jittor as jt
import numpy as np
import utils

# %%
ls = utils.Losser()
a = jt.Var(np.array([1,2,3]))
b = jt.Var(np.array([4,5,6]))

ls.psnr(a, a+0.1 )
# Out:
# array([68.130806], dtype=float32)

# %%
from PIL import Image
import matplotlib.pyplot as plt

imgsource = Image.open("testimage.png").convert("L")
img1 = np.array(imgsource)
noise = 0.01 * np.random.random(size = img1.shape)
img2 = img1+noise

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
ls.mse(img1,img2).item(),ls.psnr(img1,img2).item()
# Out:
# (3.3335242282330874e-05, 92.90176744919243)

# %%
x = jt.array([[1,2],[3,4]])
y = jt.array([[5,6],[7,8]])
jt.concat([x,y],dim= 0)
# Out:
# jt.Var([[1 2]
#         [3 4]
#         [5 6]
#         [7 8]], dtype=int32)
